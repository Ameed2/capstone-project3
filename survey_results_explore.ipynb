# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Datasets/stack-overflow-developer-survey-2025/survey_results_public.csv")
# Out:
# C:\Users\victory tech\AppData\Local\Temp\ipykernel_5400\2889501769.py:1: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Datasets/stack-overflow-developer-survey-2025/survey_results_public.csv")

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# 4  Independent contractor, freelancer, or self-em...
#
#                                     EmploymentAddl  WorkExp  \
# 0  Caring for dependents (children, elderly, etc.)      8.0
# 1                                              NaN      2.0
# 2                                None of the above     10.0
# 3                                None of the above      4.0
# 4  Caring for dependents (children, elderly, etc.)     21.0
#
#                                      LearnCodeChoose  \
# 0  Yes, I am not new to coding but am learning ne...
# 1  Yes, I am not new to coding but am learning ne...
# 2  Yes, I am not new to coding but am learning ne...
# 3  Yes, I am not new to coding but am learning ne...
# 4  No, I am not new to coding and did not learn n...
#
#                                            LearnCode  \
# 0  Online Courses or Certification (includes all ...
# 1  Online Courses or Certification (includes all ...
# 2  Online Courses or Certification (includes all ...
# 3  Other online resources (e.g. standard search, ...
# 4                                                NaN
#
#                                          LearnCodeAI  \
# 0  Yes, I learned how to use AI-enabled tools for...
# 1  Yes, I learned how to use AI-enabled tools for...
# 2  Yes, I learned how to use AI-enabled tools for...
# 3  Yes, I learned how to use AI-enabled tools for...
# 4  Yes, I learned how to use AI-enabled tools for...
#
#                                           AILearnHow  YearsCode  \
# 0                AI CodeGen tools or AI-enabled apps       14.0
# 1                AI CodeGen tools or AI-enabled apps       10.0
# 2  AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 3  AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 4  Technical documentation (is generated for/by t...       22.0
#
#                 DevType                   OrgSize                  ICorPM  \
# 0     Developer, mobile        20 to 99 employees          People manager
# 1   Developer, back-end      500 to 999 employees  Individual contributor
# 2  Developer, front-end                       NaN                     NaN
# 3   Developer, back-end  10,000 or more employees  Individual contributor
# 4   Engineering manager                       NaN                     NaN
#
#                                           RemoteWork  \
# 0                                             Remote
# 1  Hybrid (some in-person, leans heavy to flexibi...
# 2                                                NaN
# 3                                             Remote
# 4                                                NaN
#
#                                    PurchaseInfluence  TechEndorseIntro  \
# 0  Yes, I influenced the purchase of a substantia...              Work
# 1                                                 No  Personal Project
# 2                                                 No              Work
# 3                                                 No  Personal Project
# 4  Yes, I endorsed a tool that was open-source an...              Work
#
#    TechEndorse_1  TechEndorse_2  TechEndorse_3  TechEndorse_4  TechEndorse_5  \
# 0           10.0            7.0            9.0            6.0            3.0
# 1           13.0            1.0            2.0            9.0            4.0
# 2           12.0            2.0            3.0            7.0            5.0
# 3            2.0           12.0            6.0            5.0           13.0
# 4            6.0            3.0            1.0            9.0           10.0
#
#    TechEndorse_6  TechEndorse_7  TechEndorse_8  TechEndorse_9  TechEndorse_13  \
# 0           11.0           12.0            1.0            8.0            14.0
# 1            3.0           12.0            5.0            7.0            14.0
# 2           10.0           13.0            1.0            4.0            14.0
# 3            3.0            8.0           11.0            7.0            14.0
# 4            8.0            7.0            4.0            2.0            14.0
#
#   TechEndorse_13_TEXT  TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# 0                 NaN          15.0           7.0           8.0          12.0
# 1                 NaN          14.0           1.0          13.0          10.0
# 2                 NaN           8.0           1.0           2.0          12.0
# 3                 NaN          10.0           5.0           8.0           4.0
# 4                 NaN           7.0          13.0           3.0           9.0
#
#    TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  TechOppose_16  \
# 0          11.0           1.0            6.0           13.0            3.0
# 1           9.0           3.0            4.0            2.0            5.0
# 2          13.0           3.0            9.0            4.0           11.0
# 3          13.0          12.0            2.0            7.0            1.0
# 4          12.0           6.0            1.0            8.0           14.0
#
#    TechOppose_15 TechOppose_15_TEXT                      Industry  \
# 0           16.0                NaN                       Fintech
# 1           15.0                NaN  Retail and Consumer Services
# 2           15.0                NaN          Software Development
# 3           15.0                NaN  Retail and Consumer Services
# 4           15.0                NaN          Software Development
#
#    JobSatPoints_1  JobSatPoints_2  JobSatPoints_3  JobSatPoints_4  \
# 0             3.0             1.0             4.0             9.0
# 1            10.0             8.0             3.0             9.0
# 2             9.0             6.0             7.0            11.0
# 3             1.0             2.0             4.0             5.0
# 4             9.0             4.0            11.0            13.0
#
#    JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# 0             5.0            10.0            12.0            11.0
# 1            12.0             1.0             6.0             2.0
# 2             8.0            12.0             1.0             5.0
# 3             6.0             7.0             8.0             9.0
# 4            14.0             8.0             6.0             5.0
#
#    JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  JobSatPoints_13  \
# 0             2.0              6.0              7.0             13.0
# 1            11.0              4.0              7.0             13.0
# 2             2.0              4.0              3.0             13.0
# 3            10.0             11.0             12.0             13.0
# 4             7.0              2.0              1.0             12.0
#
#    JobSatPoints_14  JobSatPoints_15  JobSatPoints_16 JobSatPoints_15_TEXT  \
# 0             14.0             15.0              8.0                  NaN
# 1             14.0             15.0              5.0                  NaN
# 2             14.0             15.0             10.0                  NaN
# 3             14.0             15.0              3.0                  NaN
# 4             10.0             15.0              3.0                  NaN
#
#        AIThreat                                            NewRole  \
# 0  I'm not sure  I have neither consider or transitioned into a...
# 1  I'm not sure  I have transitioned into a new career and/or i...
# 2            No  I have transitioned into a new career and/or i...
# 3            No  I have neither consider or transitioned into a...
# 4            No  I have neither consider or transitioned into a...
#
#    ToolCountWork  ToolCountPersonal      Country                  Currency  \
# 0            7.0                3.0      Ukraine         EUR European Euro
# 1            6.0                5.0  Netherlands         EUR European Euro
# 2            3.0                3.0      Ukraine     UAH Ukrainian hryvnia
# 3            NaN                NaN      Ukraine         EUR European Euro
# 4            4.0                3.0      Ukraine  USD United States dollar
#
#    CompTotal LanguageChoice  \
# 0    52800.0            Yes
# 1    90000.0            Yes
# 2  2214000.0            Yes
# 3    31200.0            Yes
# 4    60000.0            Yes
#
#                               LanguageHaveWorkedWith  \
# 0                   Bash/Shell (all shells);Dart;SQL
# 1                                               Java
# 2                Dart;HTML/CSS;JavaScript;TypeScript
# 3                                    Java;Kotlin;SQL
# 4  C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#
#                      LanguageWantToWorkWith  \
# 0                                      Dart
# 1                         Java;Python;Swift
# 2       Dart;HTML/CSS;JavaScript;TypeScript
# 3                               Java;Kotlin
# 4  C#;Java;JavaScript;Python;SQL;TypeScript
#
#                             LanguageAdmired LanguagesHaveEntry  \
# 0                                      Dart                NaN
# 1                                      Java                NaN
# 2       Dart;HTML/CSS;JavaScript;TypeScript                NaN
# 3                               Java;Kotlin                NaN
# 4  C#;Java;JavaScript;Python;SQL;TypeScript                NaN
#
#   LanguagesWantEntry DatabaseChoice  \
# 0                NaN            Yes
# 1                NaN            Yes
# 2                NaN            Yes
# 3                NaN             No
# 4                NaN            Yes
#
#                               DatabaseHaveWorkedWith  \
# 0                         Cloud Firestore;PostgreSQL
# 1                                   Dynamodb;MongoDB
# 2                           MongoDB;MySQL;PostgreSQL
# 3                                                NaN
# 4  Elasticsearch;Microsoft SQL Server;MySQL;Oracl...
#
#                DatabaseWantToWorkWith                  DatabaseAdmired  \
# 0                                 NaN                              NaN
# 1                    Dynamodb;MongoDB                 Dynamodb;MongoDB
# 2  Firebase Realtime Database;MongoDB                          MongoDB
# 3                                 NaN                              NaN
# 4     Elasticsearch;Oracle;PostgreSQL  Elasticsearch;Oracle;PostgreSQL
#
#   DatabaseHaveEntry DatabaseWantEntry PlatformChoice  \
# 0               NaN               NaN            Yes
# 1               NaN               NaN            Yes
# 2               NaN               NaN            Yes
# 3               NaN               NaN            Yes
# 4               NaN               NaN            Yes
#
#                               PlatformHaveWorkedWith  \
# 0  Amazon Web Services (AWS);Cloudflare;Firebase;...
# 1  Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 2                          Datadog;Firebase;npm;pnpm
# 3             Amazon Web Services (AWS);Google Cloud
# 4  Amazon Web Services (AWS);APT;Docker;Make;Mave...
#
#                               PlatformWantToWorkWith  \
# 0                                                NaN
# 1  Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 2   Amazon Web Services (AWS);Firebase;npm;pnpm;Vite
# 3             Amazon Web Services (AWS);Google Cloud
# 4  Amazon Web Services (AWS);APT;Docker;Maven (bu...
#
#                                      PlatformAdmired PlatformHaveEntry  \
# 0                                                NaN               NaN
# 1  Amazon Web Services (AWS);Datadog;Docker;Homeb...               NaN
# 2                                  Firebase;npm;pnpm               NaN
# 3             Amazon Web Services (AWS);Google Cloud               NaN
# 4  Amazon Web Services (AWS);APT;Docker;Maven (bu...               NaN
#
#   PlatformWantEntry WebframeChoice                     WebframeHaveWorkedWith  \
# 0               NaN             No                                        NaN
# 1               NaN            Yes                                Spring Boot
# 2               NaN            Yes                      Next.js;Node.js;React
# 3               NaN            Yes                                Spring Boot
# 4               NaN            Yes  Angular;ASP.NET;ASP.NET Core;Flask;jQuery
#
#        WebframeWantToWorkWith             WebframeAdmired WebframeHaveEntry  \
# 0                         NaN                         NaN               NaN
# 1                 Spring Boot                 Spring Boot               NaN
# 2       Next.js;Node.js;React       Next.js;Node.js;React               NaN
# 3                 Spring Boot                 Spring Boot               NaN
# 4  Angular;ASP.NET Core;Flask  Angular;ASP.NET Core;Flask               NaN
#
#   WebframeWantEntry DevEnvsChoice  \
# 0               NaN           Yes
# 1               NaN           Yes
# 2          Solid.js           Yes
# 3               NaN            No
# 4               NaN           Yes
#
#                                DevEnvsHaveWorkedWith  \
# 0  Android Studio;Notepad++;Visual Studio;Visual ...
# 1     IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 2                                 Visual Studio Code
# 3                                                NaN
# 4  Eclipse;IntelliJ IDEA;Jupyter Notebook/Jupyter...
#
#                                DevEnvsWantToWorkWith  \
# 0                                                NaN
# 1     IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 2                        Visual Studio Code;Windsurf
# 3                                                NaN
# 4  IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...
#
#                                       DevEnvsAdmired DevEnvHaveEntry  \
# 0                                                NaN             NaN
# 1     IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode             NaN
# 2                                 Visual Studio Code             NaN
# 3                                                NaN             NaN
# 4  IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...             NaN
#
#   DevEnvWantEntry                SOTagsHaveWorkedWith  \
# 0             NaN                                 NaN
# 1             NaN                                 NaN
# 2             NaN                       Google Gemini
# 3             NaN                      Amazon Bedrock
# 4             NaN  Large Language Model;Google Gemini
#
#       SOTagsWantToWorkWith         SOTagsAdmired SOTagsHaveEntry  \
# 0                      NaN                   NaN             NaN
# 1                      NaN                   NaN             NaN
# 2  Google Gemini;Shadcn/ui         Google Gemini             NaN
# 3                      NaN                   NaN             NaN
# 4     Large Language Model  Large Language Model             NaN
#
#   SOTagsWant Entry         OpSysPersonal use  \
# 0              NaN     Windows;MacOS;Android
# 1              NaN  Windows;MacOS;iOS;iPadOS
# 2              NaN             MacOS;Android
# 3              NaN                   Windows
# 4              NaN               Windows;iOS
#
#               OpSysProfessional use  \
# 0  Windows;MacOS;Android;iOS;iPadOS
# 1                             MacOS
# 2                             MacOS
# 3                    Windows;Ubuntu
# 4             Windows;Ubuntu;Debian
#
#                 OfficeStackAsyncHaveWorkedWith OfficeStackAsyncWantToWorkWith  \
# 0  Confluence;GitHub;GitLab;Jira;Markdown File                  Markdown File
# 1                       Confluence;GitHub;Jira         Confluence;GitHub;Jira
# 2                           GitHub;GitLab;Jira             GitHub;GitLab;Jira
# 3                             GitLab;Jira;Miro                    GitLab;Jira
# 4                     Azure Devops;GitHub;Jira       Azure Devops;GitHub;Jira
#
#     OfficeStackAsyncAdmired OfficeStackHaveEntry OfficeStackWantEntry  \
# 0             Markdown File                  NaN                  NaN
# 1    Confluence;GitHub;Jira                  NaN                  NaN
# 2        GitHub;GitLab;Jira                  NaN                  NaN
# 3               GitLab;Jira                  NaN                  NaN
# 4  Azure Devops;GitHub;Jira                  NaN                  NaN
#
#                           CommPlatformHaveWorkedWith  \
# 0  Stack Overflow;Reddit;GitHub (public projects,...
# 1  Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 2   Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 3             Stack Overflow;Reddit;YouTube;LinkedIn
# 4  Stack Overflow;Stack Exchange;GitHub (public p...
#
#                           CommPlatformWantToWorkWith  \
# 0                                                NaN
# 1  Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 2   Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 3  Stack Overflow;Reddit;GitHub (public projects,...
# 4  Stack Overflow;Stack Exchange;GitHub (public p...
#
#                                  CommPlatformAdmired CommPlatformHaveEntr  \
# 0                                                NaN                  NaN
# 1  Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...                  NaN
# 2   Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn                  NaN
# 3             Stack Overflow;Reddit;YouTube;LinkedIn                  NaN
# 4  Stack Overflow;Stack Exchange;GitHub (public p...                  NaN
#
#   CommPlatformWantEntr AIModelsChoice  \
# 0                  NaN            Yes
# 1                  NaN            Yes
# 2                  NaN            Yes
# 3                  NaN             No
# 4                  NaN            Yes
#
#                               AIModelsHaveWorkedWith  \
# 0  openAI GPT (chatbot models);openAI Image gener...
# 1                        openAI GPT (chatbot models)
# 2  Gemini (Flash general purpose models);openAI G...
# 3                                                NaN
# 4                        openAI GPT (chatbot models)
#
#                               AIModelsWantToWorkWith  \
# 0                                                NaN
# 1                        openAI GPT (chatbot models)
# 2  Gemini (Flash general purpose models);Gemini (...
# 3                                                NaN
# 4                        openAI GPT (chatbot models)
#
#                                      AIModelsAdmired AIModelsHaveEntry  \
# 0                                                NaN               NaN
# 1                        openAI GPT (chatbot models)               NaN
# 2  Gemini (Flash general purpose models);openAI G...               NaN
# 3                                                NaN               NaN
# 4                        openAI GPT (chatbot models)               NaN
#
#   AIModelsWantEntry                SOAccount                      SOVisitFreq  \
# 0               NaN                      Yes             A few times per week
# 1               NaN  Not sure/can't remember           Multiple times per day
# 2               NaN  Not sure/can't remember             A few times per week
# 3               NaN                      Yes  A few times per month or weekly
# 4               NaN                       No  A few times per month or weekly
#
#                 SODuration                                         SOPartFreq  \
# 0   Between 5 and 10 years  I have never participated in Q&A on Stack Over...
# 1  Between 10 and 15 years              Infrequently, less than once per year
# 2   Between 5 and 10 years              Infrequently, less than once per year
# 3    Between 3 and 5 years  I have never participated in Q&A on Stack Over...
# 4   Between 5 and 10 years              Infrequently, less than once per year
#
#                                       SO_Dev_Content  SO_Actions_1  \
# 0                                                NaN           1.0
# 1  Chat (people);Message Boards;Long-form article...           6.0
# 2  Chat (people);Videos;Lists of recommendations ...           3.0
# 3                               Videos;Chat (bot/AI)           1.0
# 4                                 Long-form articles           1.0
#
#    SO_Actions_16  SO_Actions_3  SO_Actions_4  SO_Actions_5  SO_Actions_6  \
# 0            NaN           6.0           2.0           3.0           7.0
# 1            NaN           5.0           8.0           2.0           4.0
# 2            NaN           4.0           5.0           1.0           2.0
# 3            NaN           4.0           5.0           6.0           7.0
# 4            NaN           7.0           4.0           2.0           5.0
#
#    SO_Actions_9  SO_Actions_7  SO_Actions_10  SO_Actions_15  \
# 0           8.0           9.0           11.0           15.0
# 1           9.0          10.0           11.0           15.0
# 2           7.0           9.0           11.0           15.0
# 3           8.0           9.0           11.0           15.0
# 4          10.0           6.0           12.0           15.0
#
#   SO_Actions_15_TEXT          SOComm              SOFriction  \
# 0                NaN         Neutral    Rarely, almost never
# 1                NaN   Yes, somewhat  About half of the time
# 2                NaN         Neutral  About half of the time
# 3                NaN         Neutral    Rarely, almost never
# 4                NaN  No, not really    Rarely, almost never
#
#                                       AISelect       AISent  \
# 0  Yes, I use AI tools monthly or infrequently  Indifferent
# 1                   Yes, I use AI tools weekly  Indifferent
# 2                    Yes, I use AI tools daily    Favorable
# 3                   Yes, I use AI tools weekly    Favorable
# 4                   Yes, I use AI tools weekly    Favorable
#
#                         AIAcc                                      AIComplex  \
# 0  Neither trust nor distrust                  Bad at handling complex tasks
# 1  Neither trust nor distrust                  Bad at handling complex tasks
# 2              Somewhat trust  Neither good or bad at handling complex tasks
# 3              Somewhat trust                  Bad at handling complex tasks
# 4  Neither trust nor distrust  Good, but not great at handling complex tasks
#
#                         AIToolCurrently partially AI  \
# 0  Learning about a codebase;Writing code;Search ...
# 1              Learning new concepts or technologies
# 2  Documenting code;Debugging or fixing code;Test...
# 3                                                NaN
# 4  Learning about a codebase;Writing code;Debuggi...
#
#             AIToolDon't plan to use AI for this task  \
# 0  Project planning;Deployment and monitoring;Lea...
# 1  Learning about a codebase;Project planning;Com...
# 2                                                NaN
# 3  Project planning;Documenting code;Testing code...
# 4  Project planning;Documenting code;Testing code...
#
#                       AIToolPlan to partially use AI  \
# 0  Documenting code;Debugging or fixing code;Test...
# 1  Writing code;Documenting code;Debugging or fix...
# 2  Project planning;Committing and reviewing code...
# 3  Learning about a codebase;Writing code;Debuggi...
# 4               Generating content or synthetic data
#
#                          AIToolPlan to mostly use AI  \
# 0                                                NaN
# 1                                                NaN
# 2  Learning about a codebase;Writing code;Generat...
# 3  Search for answers;Generating content or synth...
# 4                                                NaN
#
#   AIToolCurrently mostly AI  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                        AIFrustration AIExplain  \
# 0  AI solutions that are almost right, but not quite        No
# 1  AI solutions that are almost right, but not qu...        No
# 2  AI solutions that are almost right, but not qu...        No
# 3  AI solutions that are almost right, but not qu...        NO
# 4  AI solutions that are almost right, but not quite    partly
#
#                                             AIAgents            AIAgentChange  \
# 0  Yes, I use AI agents at work monthly or infreq...  Not at all or minimally
# 1                            No, and I don't plan to  Not at all or minimally
# 2                Yes, I use AI agents at work weekly            Yes, somewhat
# 3  Yes, I use AI agents at work monthly or infreq...  Not at all or minimally
# 4                            No, and I don't plan to   Yes, to a great extent
#
#            AIAgent_Uses                  AgentUsesGeneral  \
# 0  Software engineering                               NaN
# 1                   NaN                               NaN
# 2  Software engineering  Multi-platform search enablement
# 3  Software engineering               Language processing
# 4                   NaN                               NaN
#
#                          AIAgentImpactSomewhat agree  \
# 0  AI agents have increased my productivity.;AI a...
# 1                                                NaN
# 2  AI agents have increased my productivity.;AI a...
# 3  AI agents have accelerated my learning about n...
# 4                                                NaN
#
#                                 AIAgentImpactNeutral  \
# 0  AI agents have helped me automate repetitive t...
# 1                                                NaN
# 2  AI agents have improved the quality of my code...
# 3  AI agents have increased my productivity.;AI a...
# 4                                                NaN
#
#                       AIAgentImpactSomewhat disagree  \
# 0                                                NaN
# 1                                                NaN
# 2  AI agents have improved collaboration within m...
# 3  AI agents have helped me automate repetitive t...
# 4                                                NaN
#
#   AIAgentImpactStrongly agree AIAgentImpactStrongly disagree  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#                             AIAgentChallengesNeutral  \
# 0  I am concerned about the accuracy of the infor...
# 1  It takes significant time and effort to learn ...
# 2  It takes significant time and effort to learn ...
# 3  It takes significant time and effort to learn ...
# 4  Integrating AI agents with my existing tools a...
#
#                   AIAgentChallengesSomewhat disagree  \
# 0  Integrating AI agents with my existing tools a...
# 1                                                NaN
# 2  My company's IT and/or InfoSec teams have stri...
# 3                                                NaN
# 4                                                NaN
#
#                      AIAgentChallengesStrongly agree  \
# 0  The cost of using certain AI agent platforms i...
# 1  I am concerned about the accuracy of the infor...
# 2                                                NaN
# 3  I am concerned about the accuracy of the infor...
# 4  I am concerned about the accuracy of the infor...
#
#                      AIAgentChallengesSomewhat agree  \
# 0                                                NaN
# 1  Integrating AI agents with my existing tools a...
# 2  I am concerned about the accuracy of the infor...
# 3  Integrating AI agents with my existing tools a...
# 4  It takes significant time and effort to learn ...
#
#   AIAgentChallengesStrongly disagree AIAgentKnowledge AIAgentKnowWrite  \
# 0                                NaN              NaN              NaN
# 1                                NaN              NaN              NaN
# 2                                NaN            Redis              NaN
# 3                                NaN              NaN              NaN
# 4                                NaN              NaN              NaN
#
#   AIAgentOrchestration AIAgentOrchWrite AIAgentObserveSecure AIAgentObsWrite  \
# 0            Vertex AI              NaN                  NaN             NaN
# 1                  NaN              NaN                  NaN             NaN
# 2                  NaN              NaN                  NaN             NaN
# 3                  NaN              NaN                  NaN             NaN
# 4                  NaN              NaN                  NaN             NaN
#
#                                     AIAgentExternal AIAgentExtWrite  \
# 0                                           ChatGPT             NaN
# 1                                               NaN             NaN
# 2  ChatGPT;Claude Code;GitHub Copilot;Google Gemini             NaN
# 3                               ChatGPT;Claude Code             NaN
# 4                                               NaN             NaN
#
#                                              AIHuman  \
# 0                    When I don’t trust AI’s answers
# 1  When I don’t trust AI’s answers;When I want to...
# 2  When I don’t trust AI’s answers;When I want to...
# 3  When I don’t trust AI’s answers;When I want to...
# 4                    When I don’t trust AI’s answers
#
#                                               AIOpen  ConvertedCompYearly  \
# 0              Troubleshooting, profiling, debugging              61256.0
# 1                          All skills. AI is a flop.             104413.0
# 2  Understand how things actually work, problem s...              53061.0
# 3                                                NaN              36197.0
# 4  critical thinking, the skill to define the tas...              60000.0
#
#    JobSat
# 0    10.0
# 1     9.0
# 2     8.0
# 3     6.0
# 4     7.0

# %%
df.shape
# Out:
# (49191, 172)

# %%
for col in df.columns:
    print(col)
# Out:
# ResponseId
# MainBranch
# Age
# EdLevel
# Employment
# EmploymentAddl
# WorkExp
# LearnCodeChoose
# LearnCode
# LearnCodeAI
# AILearnHow
# YearsCode
# DevType
# OrgSize
# ICorPM
# RemoteWork
# PurchaseInfluence
# TechEndorseIntro
# TechEndorse_1
# TechEndorse_2
# TechEndorse_3
# TechEndorse_4
# TechEndorse_5
# TechEndorse_6
# TechEndorse_7
# TechEndorse_8
# TechEndorse_9
# TechEndorse_13
# TechEndorse_13_TEXT
# TechOppose_1
# TechOppose_2
# TechOppose_3
# TechOppose_5
# TechOppose_7
# TechOppose_9
# TechOppose_11
# TechOppose_13
# TechOppose_16
# TechOppose_15
# TechOppose_15_TEXT
# Industry
# JobSatPoints_1
# JobSatPoints_2
# JobSatPoints_3
# JobSatPoints_4
# JobSatPoints_5
# JobSatPoints_6
# JobSatPoints_7
# JobSatPoints_8
# JobSatPoints_9
# JobSatPoints_10
# JobSatPoints_11
# JobSatPoints_13
# JobSatPoints_14
# JobSatPoints_15
# JobSatPoints_16
# JobSatPoints_15_TEXT
# AIThreat
# NewRole
# ToolCountWork
# ToolCountPersonal
# Country
# Currency
# CompTotal
# LanguageChoice
# LanguageHaveWorkedWith
# LanguageWantToWorkWith
# LanguageAdmired
# LanguagesHaveEntry
# LanguagesWantEntry
# DatabaseChoice
# DatabaseHaveWorkedWith
# DatabaseWantToWorkWith
# DatabaseAdmired
# DatabaseHaveEntry
# DatabaseWantEntry
# PlatformChoice
# PlatformHaveWorkedWith
# PlatformWantToWorkWith
# PlatformAdmired
# PlatformHaveEntry
# PlatformWantEntry
# WebframeChoice
# WebframeHaveWorkedWith
# WebframeWantToWorkWith
# WebframeAdmired
# WebframeHaveEntry
# WebframeWantEntry
# DevEnvsChoice
# DevEnvsHaveWorkedWith
# DevEnvsWantToWorkWith
# DevEnvsAdmired
# DevEnvHaveEntry
# DevEnvWantEntry
# SOTagsHaveWorkedWith
# SOTagsWantToWorkWith
# SOTagsAdmired
# SOTagsHaveEntry
# SOTagsWant Entry
# OpSysPersonal use
# OpSysProfessional use
# OfficeStackAsyncHaveWorkedWith
# OfficeStackAsyncWantToWorkWith
# OfficeStackAsyncAdmired
# OfficeStackHaveEntry
# OfficeStackWantEntry
# CommPlatformHaveWorkedWith
# CommPlatformWantToWorkWith
# CommPlatformAdmired
# CommPlatformHaveEntr
# CommPlatformWantEntr
# AIModelsChoice
# AIModelsHaveWorkedWith
# AIModelsWantToWorkWith
# AIModelsAdmired
# AIModelsHaveEntry
# AIModelsWantEntry
# SOAccount
# SOVisitFreq
# SODuration
# SOPartFreq
# SO_Dev_Content
# SO_Actions_1
# SO_Actions_16
# SO_Actions_3
# SO_Actions_4
# SO_Actions_5
# SO_Actions_6
# SO_Actions_9
# SO_Actions_7
# SO_Actions_10
# SO_Actions_15
# SO_Actions_15_TEXT
# SOComm
# SOFriction
# AISelect
# AISent
# AIAcc
# AIComplex
# AIToolCurrently partially AI
# AIToolDon't plan to use AI for this task
# AIToolPlan to partially use AI
# AIToolPlan to mostly use AI
# AIToolCurrently mostly AI
# AIFrustration
# AIExplain
# AIAgents
# AIAgentChange
# AIAgent_Uses
# AgentUsesGeneral
# AIAgentImpactSomewhat agree
# AIAgentImpactNeutral
# AIAgentImpactSomewhat disagree
# AIAgentImpactStrongly agree
# AIAgentImpactStrongly disagree
# AIAgentChallengesNeutral
# AIAgentChallengesSomewhat disagree
# AIAgentChallengesStrongly agree
# AIAgentChallengesSomewhat agree
# AIAgentChallengesStrongly disagree
# AIAgentKnowledge
# AIAgentKnowWrite
# AIAgentOrchestration
# AIAgentOrchWrite
# AIAgentObserveSecure
# AIAgentObsWrite
# AIAgentExternal
# AIAgentExtWrite
# AIHuman
# AIOpen
# ConvertedCompYearly
# JobSat

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), object(119)
# memory usage: 64.6+ MB

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum().sort_values(ascending=False)
# Out:
# AIAgentObsWrite                             48927
# SOTagsWant Entry                            48761
# SOTagsHaveEntry                             48733
# AIModelsWantEntry                           48716
# AIAgentOrchWrite                            48713
# JobSatPoints_15_TEXT                        48527
# AIAgentKnowWrite                            48425
# AIModelsHaveEntry                           48415
# SO_Actions_15_TEXT                          48368
# AIAgentExtWrite                             48332
# CommPlatformWantEntr                        48007
# CommPlatformHaveEntr                        47715
# DatabaseWantEntry                           47658
# OfficeStackWantEntry                        47574
# TechOppose_15_TEXT                          47544
# TechEndorse_13_TEXT                         47182
# DevEnvWantEntry                             47079
# DatabaseHaveEntry                           47041
# OfficeStackHaveEntry                        46602
# WebframeWantEntry                           46561
# AIAgentObserveSecure                        46499
# DevEnvHaveEntry                             46429
# PlatformWantEntry                           46091
# LanguagesWantEntry                          46041
# WebframeHaveEntry                           45897
# AIAgentKnowledge                            45790
# AIAgentOrchestration                        45431
# AIAgentImpactStrongly disagree              45412
# PlatformHaveEntry                           45234
# LanguagesHaveEntry                          45209
# AIAgentImpactSomewhat disagree              43400
# AgentUsesGeneral                            43386
# AIAgentImpactStrongly agree                 42504
# AIAgentExternal                             40859
# AIAgentChallengesStrongly disagree          39877
# AIAgentImpactNeutral                        39516
# AIAgentImpactSomewhat agree                 39045
# AIToolCurrently mostly AI                   37966
# AIModelsAdmired                             37907
# AIModelsWantToWorkWith                      37346
# AIAgentChallengesSomewhat disagree          37066
# SOTagsAdmired                               36951
# AIAgent_Uses                                36871
# AIToolPlan to mostly use AI                 36373
# SOTagsWantToWorkWith                        35604
# WebframeAdmired                             33482
# AIModelsHaveWorkedWith                      32910
# DatabaseAdmired                             31896
# WebframeWantToWorkWith                      31552
# PlatformAdmired                             31369
# SOTagsHaveWorkedWith                        31269
# PlatformWantToWorkWith                      29776
# DevEnvsAdmired                              29699
# DatabaseWantToWorkWith                      29458
# DevEnvsWantToWorkWith                       28577
# AIToolCurrently partially AI                28163
# AIAgentChallengesNeutral                    27896
# AIAgentChallengesSomewhat agree             27244
# OfficeStackAsyncAdmired                     26983
# AIOpen                                      26651
# AIToolPlan to partially use AI              26635
# SO_Dev_Content                              26355
# CommPlatformAdmired                         26314
# WebframeHaveWorkedWith                      26199
# AIAgentChallengesStrongly agree             26083
# OfficeStackAsyncWantToWorkWith              25985
# CommPlatformWantToWorkWith                  25840
# LanguageAdmired                             25721
# ConvertedCompYearly                         25244
# PlatformHaveWorkedWith                      24933
# SO_Actions_16                               24851
# CompTotal                                   24325
# JobSatPoints_8                              24248
# JobSatPoints_4                              24248
# JobSatPoints_13                             24248
# JobSatPoints_15                             24248
# JobSatPoints_11                             24248
# JobSatPoints_14                             24248
# JobSatPoints_6                              24248
# JobSatPoints_5                              24248
# JobSatPoints_10                             24248
# JobSatPoints_9                              24248
# JobSatPoints_7                              24248
# JobSatPoints_1                              24248
# JobSatPoints_2                              24248
# JobSatPoints_3                              24248
# JobSatPoints_16                             24248
# AIToolDon't plan to use AI for this task    23810
# DatabaseHaveWorkedWith                      23641
# ToolCountPersonal                           23609
# DevEnvsHaveWorkedWith                       23172
# SO_Actions_3                                22931
# SO_Actions_9                                22931
# SO_Actions_1                                22931
# SO_Actions_10                               22931
# SO_Actions_7                                22931
# SO_Actions_6                                22931
# SO_Actions_5                                22931
# SO_Actions_15                               22931
# SO_Actions_4                                22931
# AIExplain                                   22605
# JobSat                                      22521
# LanguageWantToWorkWith                      22112
# ToolCountWork                               21580
# AILearnHow                                  20934
# OpSysProfessional use                       20308
# AIHuman                                     19997
# OfficeStackAsyncHaveWorkedWith              19333
# CommPlatformHaveWorkedWith                  19126
# AIModelsChoice                              18952
# SOFriction                                  18404
# DevEnvsChoice                               18112
# WebframeChoice                              17998
# PlatformChoice                              17929
# OpSysPersonal use                           17774
# AIFrustration                               17669
# LanguageHaveWorkedWith                      17520
# AIAgentChange                               17513
# DatabaseChoice                              17503
# SOComm                                      17485
# AIAgents                                    17272
# LanguageChoice                              16977
# SOPartFreq                                  16963
# SODuration                                  16564
# SOVisitFreq                                 16481
# SOAccount                                   16394
# ICorPM                                      15948
# AIComplex                                   15908
# AIAcc                                       15894
# AISent                                      15724
# LearnCode                                   15635
# Industry                                    15549
# AISelect                                    15471
# RemoteWork                                  15411
# OrgSize                                     15013
# TechOppose_2                                14932
# TechOppose_3                                14932
# TechOppose_16                               14932
# TechOppose_15                               14932
# TechOppose_13                               14932
# TechOppose_11                               14932
# TechOppose_9                                14932
# TechOppose_7                                14932
# TechOppose_5                                14932
# TechOppose_1                                14932
# Country                                     13754
# Currency                                    13754
# NewRole                                     13664
# TechEndorse_13                              13216
# TechEndorse_5                               13216
# TechEndorse_4                               13216
# TechEndorse_6                               13216
# TechEndorse_3                               13216
# TechEndorse_2                               13216
# TechEndorse_9                               13216
# TechEndorse_7                               13216
# TechEndorse_1                               13216
# TechEndorse_8                               13216
# AIThreat                                    13113
# PurchaseInfluence                           11754
# TechEndorseIntro                            11635
# WorkExp                                      6298
# YearsCode                                    6149
# DevType                                      5511
# EmploymentAddl                               4316
# LearnCodeAI                                  3990
# LearnCodeChoose                              2333
# EdLevel                                      1042
# Employment                                    852
# ResponseId                                      0
# MainBranch                                      0
# Age                                             0
# dtype: int64

# %%
df["CompTotal"].head(10)

# %%
((df.isnull().sum() / len(df)) * 100).sort_values(ascending=False)
# Out:
# AIAgentObsWrite                             99.463316
# SOTagsWant Entry                            99.125856
# SOTagsHaveEntry                             99.068935
# AIModelsWantEntry                           99.034376
# AIAgentOrchWrite                            99.028278
# JobSatPoints_15_TEXT                        98.650160
# AIAgentKnowWrite                            98.442805
# AIModelsHaveEntry                           98.422476
# SO_Actions_15_TEXT                          98.326930
# AIAgentExtWrite                             98.253746
# CommPlatformWantEntr                        97.593056
# CommPlatformHaveEntr                        96.999451
# DatabaseWantEntry                           96.883576
# OfficeStackWantEntry                        96.712813
# TechOppose_15_TEXT                          96.651827
# TechEndorse_13_TEXT                         95.915920
# DevEnvWantEntry                             95.706532
# DatabaseHaveEntry                           95.629282
# OfficeStackHaveEntry                        94.736842
# WebframeWantEntry                           94.653494
# AIAgentObserveSecure                        94.527454
# DevEnvHaveEntry                             94.385152
# PlatformWantEntry                           93.698034
# LanguagesWantEntry                          93.596390
# WebframeHaveEntry                           93.303653
# AIAgentKnowledge                            93.086134
# AIAgentOrchestration                        92.356325
# AIAgentImpactStrongly disagree              92.317700
# PlatformHaveEntry                           91.955846
# LanguagesHaveEntry                          91.905023
# AIAgentImpactSomewhat disagree              88.227521
# AgentUsesGeneral                            88.199061
# AIAgentImpactStrongly agree                 86.406050
# AIAgentExternal                             83.061942
# AIAgentChallengesStrongly disagree          81.065642
# AIAgentImpactNeutral                        80.331768
# AIAgentImpactSomewhat agree                 79.374276
# AIToolCurrently mostly AI                   77.180785
# AIModelsAdmired                             77.060844
# AIModelsWantToWorkWith                      75.920392
# AIAgentChallengesSomewhat disagree          75.351182
# SOTagsAdmired                               75.117400
# AIAgent_Uses                                74.954768
# AIToolPlan to mostly use AI                 73.942388
# SOTagsWantToWorkWith                        72.379094
# WebframeAdmired                             68.065296
# AIModelsHaveWorkedWith                      66.902482
# DatabaseAdmired                             64.841129
# WebframeWantToWorkWith                      64.141815
# PlatformAdmired                             63.769795
# SOTagsHaveWorkedWith                        63.566506
# PlatformWantToWorkWith                      60.531398
# DevEnvsAdmired                              60.374865
# DatabaseWantToWorkWith                      59.884938
# DevEnvsWantToWorkWith                       58.093960
# AIToolCurrently partially AI                57.252343
# AIAgentChallengesNeutral                    56.709561
# AIAgentChallengesSomewhat agree             55.384115
# OfficeStackAsyncAdmired                     54.853530
# AIOpen                                      54.178610
# AIToolPlan to partially use AI              54.146084
# SO_Dev_Content                              53.576874
# CommPlatformAdmired                         53.493525
# WebframeHaveWorkedWith                      53.259743
# AIAgentChallengesStrongly agree             53.023927
# OfficeStackAsyncWantToWorkWith              52.824704
# CommPlatformWantToWorkWith                  52.529934
# LanguageAdmired                             52.288020
# ConvertedCompYearly                         51.318331
# PlatformHaveWorkedWith                      50.686101
# SO_Actions_16                               50.519404
# CompTotal                                   49.450103
# JobSatPoints_8                              49.293570
# JobSatPoints_4                              49.293570
# JobSatPoints_13                             49.293570
# JobSatPoints_15                             49.293570
# JobSatPoints_11                             49.293570
# JobSatPoints_14                             49.293570
# JobSatPoints_6                              49.293570
# JobSatPoints_5                              49.293570
# JobSatPoints_10                             49.293570
# JobSatPoints_9                              49.293570
# JobSatPoints_7                              49.293570
# JobSatPoints_1                              49.293570
# JobSatPoints_2                              49.293570
# JobSatPoints_3                              49.293570
# JobSatPoints_16                             49.293570
# AIToolDon't plan to use AI for this task    48.403163
# DatabaseHaveWorkedWith                      48.059604
# ToolCountPersonal                           47.994552
# DevEnvsHaveWorkedWith                       47.106178
# SO_Actions_3                                46.616251
# SO_Actions_9                                46.616251
# SO_Actions_1                                46.616251
# SO_Actions_10                               46.616251
# SO_Actions_7                                46.616251
# SO_Actions_6                                46.616251
# SO_Actions_5                                46.616251
# SO_Actions_15                               46.616251
# SO_Actions_4                                46.616251
# AIExplain                                   45.953528
# JobSat                                      45.782765
# LanguageWantToWorkWith                      44.951312
# ToolCountWork                               43.869814
# AILearnHow                                  42.556565
# OpSysProfessional use                       41.283975
# AIHuman                                     40.651745
# OfficeStackAsyncHaveWorkedWith              39.301905
# CommPlatformHaveWorkedWith                  38.881096
# AIModelsChoice                              38.527373
# SOFriction                                  37.413348
# DevEnvsChoice                               36.819743
# WebframeChoice                              36.587994
# PlatformChoice                              36.447724
# OpSysPersonal use                           36.132626
# AIFrustration                               35.919172
# LanguageHaveWorkedWith                      35.616271
# AIAgentChange                               35.602041
# DatabaseChoice                              35.581712
# SOComm                                      35.545120
# AIAgents                                    35.112114
# LanguageChoice                              34.512411
# SOPartFreq                                  34.483950
# SODuration                                  33.672826
# SOVisitFreq                                 33.504096
# SOAccount                                   33.327235
# ICorPM                                      32.420565
# AIComplex                                   32.339249
# AIAcc                                       32.310789
# AISent                                      31.965197
# LearnCode                                   31.784269
# Industry                                    31.609441
# AISelect                                    31.450875
# RemoteWork                                  31.328902
# OrgSize                                     30.519811
# TechOppose_2                                30.355146
# TechOppose_3                                30.355146
# TechOppose_16                               30.355146
# TechOppose_15                               30.355146
# TechOppose_13                               30.355146
# TechOppose_11                               30.355146
# TechOppose_9                                30.355146
# TechOppose_7                                30.355146
# TechOppose_5                                30.355146
# TechOppose_1                                30.355146
# Country                                     27.960399
# Currency                                    27.960399
# NewRole                                     27.777439
# TechEndorse_13                              26.866703
# TechEndorse_5                               26.866703
# TechEndorse_4                               26.866703
# TechEndorse_6                               26.866703
# TechEndorse_3                               26.866703
# TechEndorse_2                               26.866703
# TechEndorse_9                               26.866703
# TechEndorse_7                               26.866703
# TechEndorse_1                               26.866703
# TechEndorse_8                               26.866703
# AIThreat                                    26.657315
# PurchaseInfluence                           23.894615
# TechEndorseIntro                            23.652701
# WorkExp                                     12.803155
# YearsCode                                   12.500254
# DevType                                     11.203269
# EmploymentAddl                               8.773963
# LearnCodeAI                                  8.111240
# LearnCodeChoose                              4.742737
# EdLevel                                      2.118274
# Employment                                   1.732024
# ResponseId                                   0.000000
# MainBranch                                   0.000000
# Age                                          0.000000
# dtype: float64

# %%
((df.isnull().sum() / len(df)) > 0.70).sum()
# Out:
# np.int64(45)

# %%
pd.set_option('display.max_columns', None)
df.describe()
# Out:
#          ResponseId       WorkExp     YearsCode  TechEndorse_1  TechEndorse_2  \
# count  49191.000000  42893.000000  43042.000000   35975.000000   35975.000000
# mean   24596.000000     13.367403     16.570861       7.867352       4.104211
# std    14200.362883     10.800117     11.787610       2.397432       2.275821
# min        1.000000      1.000000      1.000000       1.000000       1.000000
# 25%    12298.500000      5.000000      8.000000       7.000000       2.000000
# 50%    24596.000000     10.000000     14.000000       9.000000       4.000000
# 75%    36893.500000     20.000000     24.000000       9.000000       6.000000
# max    49191.000000    100.000000    100.000000      14.000000      14.000000
#
#        TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  \
# count   35975.000000   35975.000000   35975.000000   35975.000000
# mean        4.110271       5.678193       4.119388       5.225990
# std         2.329536       2.398084       2.437945       2.801045
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       4.000000       2.000000       3.000000
# 50%         4.000000       6.000000       4.000000       5.000000
# 75%         6.000000       8.000000       6.000000       8.000000
# max        14.000000      14.000000      14.000000      14.000000
#
#        TechEndorse_7  TechEndorse_8  TechEndorse_9  TechEndorse_13  \
# count   35975.000000   35975.000000   35975.000000    35975.000000
# mean        6.477387       4.370841       4.431661        9.854315
# std         2.331468       2.357058       2.620901        1.975692
# min         1.000000       1.000000       1.000000        1.000000
# 25%         5.000000       2.000000       2.000000       10.000000
# 50%         7.000000       4.000000       4.000000       10.000000
# 75%         8.000000       6.000000       7.000000       10.000000
# max        14.000000      14.000000      14.000000       14.000000
#
#        TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  TechOppose_7  \
# count  34259.000000  34259.000000  34259.000000  34259.000000  34259.000000
# mean       8.307948      4.524067      5.925567      4.991710      4.048980
# std        2.202164      2.282867      2.301937      2.294707      2.607443
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        8.000000      3.000000      4.000000      3.000000      2.000000
# 50%        9.000000      4.000000      6.000000      5.000000      4.000000
# 75%        9.000000      6.000000      8.000000      7.000000      6.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#        TechOppose_9  TechOppose_11  TechOppose_13  TechOppose_16  \
# count  34259.000000   34259.000000   34259.000000   34259.000000
# mean       3.799323       4.365831       5.059867       5.508538
# std        2.499468       2.557152       2.533541       2.906146
# min        1.000000       1.000000       1.000000       1.000000
# 25%        2.000000       2.000000       3.000000       3.000000
# 50%        3.000000       4.000000       5.000000       6.000000
# 75%        6.000000       6.000000       7.000000       8.000000
# max       15.000000      14.000000      15.000000      15.000000
#
#        TechOppose_15  JobSatPoints_1  JobSatPoints_2  JobSatPoints_3  \
# count   34259.000000    24943.000000    24943.000000    24943.000000
# mean        9.945766        6.867738        5.216173        7.455719
# std         2.087463        3.741490        3.660632        3.726759
# min         1.000000        1.000000        1.000000        1.000000
# 25%        10.000000        4.000000        2.000000        4.000000
# 50%        10.000000        6.000000        4.000000        7.000000
# 75%        10.000000       10.000000        8.000000       11.000000
# max        16.000000       15.000000       15.000000       15.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    24943.000000    24943.000000    24943.000000    24943.000000
# mean         9.537947        9.758209        8.194965        5.884096
# std          3.781286        3.557588        3.801257        3.900813
# min          1.000000        1.000000        1.000000        1.000000
# 25%          7.000000        7.000000        5.000000        2.000000
# 50%         10.000000       10.000000        8.000000        5.000000
# 75%         13.000000       13.000000       11.000000        9.000000
# max         15.000000       15.000000       15.000000       15.000000
#
#        JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# count    24943.000000    24943.000000     24943.000000     24943.000000
# mean         7.367799        6.744658         7.512569         5.703283
# std          4.118532        3.888845         3.847265         4.110528
# min          1.000000        1.000000         1.000000         1.000000
# 25%          4.000000        3.000000         4.000000         2.000000
# 50%          7.000000        6.000000         7.000000         5.000000
# 75%         11.000000       10.000000        11.000000         9.000000
# max         15.000000       15.000000        15.000000        15.000000
#
#        JobSatPoints_13  JobSatPoints_14  JobSatPoints_15  JobSatPoints_16  \
# count     24943.000000     24943.000000     24943.000000     24943.000000
# mean          8.563324         8.679349        14.687487         7.826685
# std           3.545288         3.633175         1.898188         4.077460
# min           1.000000         1.000000         1.000000         1.000000
# 25%           6.000000         6.000000        15.000000         4.000000
# 50%           9.000000         9.000000        15.000000         8.000000
# 75%          12.000000        12.000000        15.000000        11.000000
# max          15.000000        15.000000        15.000000        15.000000
#
#        ToolCountWork  ToolCountPersonal     CompTotal  SO_Actions_1  \
# count   27611.000000       25582.000000  2.486600e+04  26260.000000
# mean       17.734852           8.545579  2.234198e+70      4.907845
# std       269.810134          44.664738  3.523096e+72      2.682204
# min         0.000000           0.000000  0.000000e+00      1.000000
# 25%         4.000000           3.000000  5.500000e+04      3.000000
# 50%         6.000000           5.000000  1.050000e+05      5.000000
# 75%        10.000000           7.000000  2.400000e+05      7.000000
# max     10000.000000        1000.000000  5.555556e+74     15.000000
#
#        SO_Actions_16  SO_Actions_3  SO_Actions_4  SO_Actions_5  SO_Actions_6  \
# count   24340.000000  26260.000000  26260.000000  26260.000000  26260.000000
# mean        3.339770      5.718355      4.561767      4.790861      5.199657
# std         2.411404      2.628016      3.070548      2.643177      2.563562
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%         1.000000      3.000000      1.000000      3.000000      3.000000
# 50%         2.000000      6.000000      4.000000      5.000000      5.000000
# 75%         5.000000      8.000000      7.000000      7.000000      7.000000
# max        10.000000     15.000000     15.000000     15.000000     15.000000
#
#        SO_Actions_9  SO_Actions_7  SO_Actions_10  SO_Actions_15  \
# count  26260.000000  26260.000000   26260.000000   26260.000000
# mean       5.676314      4.984653       7.099505      10.079284
# std        2.310659      2.490095       2.469394       1.940928
# min        1.000000      1.000000       1.000000       1.000000
# 25%        4.000000      3.000000       6.000000      10.000000
# 50%        6.000000      5.000000       8.000000      10.000000
# 75%        7.000000      7.000000       9.000000      10.000000
# max       15.000000     15.000000      15.000000      15.000000
#
#        ConvertedCompYearly        JobSat
# count         2.394700e+04  26670.000000
# mean          1.017615e+05      7.201950
# std           4.617569e+05      1.997245
# min           1.000000e+00      0.000000
# 25%           3.817100e+04      6.000000
# 50%           7.532000e+04      8.000000
# 75%           1.205960e+05      8.000000
# max           5.000000e+07     10.000000

# %%
df["DevType"].value_counts()
# Out:
# DevType
# Developer, full-stack                            12351
# Developer, back-end                               6453
# Student                                           3008
# Architect, software or solutions                  2684
# Developer, front-end                              1974
# Developer, desktop or enterprise applications     1919
# Other (please specify):                           1825
# Developer, mobile                                 1391
# Developer, embedded applications or devices       1274
# Academic researcher                               1131
# Engineering manager                               1068
# DevOps engineer or professional                   1053
# Data engineer                                      770
# AI/ML engineer                                     677
# Data scientist                                     574
# Senior executive (C-suite, VP, etc.)               528
# System administrator                               480
# Retired                                            458
# Developer, game or graphics                        451
# Cloud infrastructure engineer                      441
# Founder, technology or otherwise                   431
# Cybersecurity or InfoSec professional              370
# Data or business analyst                           351
# Developer, QA or test                              343
# Project manager                                    302
# Applied scientist                                  297
# Support engineer or analyst                        251
# Developer, AI apps or physical AI                  236
# Product manager                                    205
# Database administrator or engineer                 175
# UX, Research Ops or UI design professional         115
# Financial analyst or engineer                       94
# Name: count, dtype: int64
